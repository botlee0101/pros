# %%
print("sai_ram")
# Out:
# sai_ram

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\SagarghotekarKalu-Co\Desktop\sai_pro\sai.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SagarghotekarKalu-Co/Desktop/sai_pro/sai.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip
# Out:
# Usage:
#   c:\Users\SagarghotekarKalu-Co\Desktop\sai_pro\sag\Scripts\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
# ...

# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/97/d8/dc2f6bff06a799a5603c414afc6de39c6351fe34892d50b6a077df3be6ac/pandas-2.1.3-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.23.2 from https://files.pythonhosted.org/packages/da/3c/3ff05c2855eee52588f489a4e607e4a61699a0742aa03ccf641c77f9eb0a/numpy-1.26.2-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 10.4 MB/s eta 0:00:00
# ...

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import math

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/26/5a/27fd341e4510257789f19a4b4be8bb90d1113b8f176c3dab562b4f21466e/matplotlib-3.8.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/ca/2a/d197a412ec474391ee878b1218cf2fe9c6e963903755887fc5654c06636a/contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/3e/3c/81364f19d2f9abbd46f0fb9a4dbac2c6fa2dd0376ebf9cdfa0a10f7461aa/fonttools-4.44.3-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
pip install seaboarn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement seaboarn (from versions: none)
# ERROR: No matching distribution found for seaboarn
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/4e/ba/ce9bd1cd4953336a0e213b29cb80bb11816f2a93de8c99f88ef0b446ad0c/scikit_learn-1.3.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/43/d0/f3cd75b62e1b90f48dbf091261b2fc7ceec14a700e308c50f6a69c83d337/scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      -------------------------------------- 60.4/60.4 kB 809.0 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import data

# %%
data
# Out:
# <module 'sklearn.datasets.data' from 'c:\\Users\\SagarghotekarKalu-Co\\Desktop\\sai_pro\\sag\\Lib\\site-packages\\sklearn\\datasets\\data\\__init__.py'>

# %%
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %%
import pandas as pd

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df=pd.DataFrame(data=iris.data,columns=iris.feature_names)

# %%
df['Target']=iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 0         0
# ...

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      Target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\SagarghotekarKalu-Co\Desktop\sai_pro\sai.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SagarghotekarKalu-Co/Desktop/sai_pro/sai.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 294.6/294.6 kB 3.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
pd.merge()

# %%
pip install opencv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread(r"C:\Users\SagarghotekarKalu-Co\Pictures\Screenshots\Regions Financial_ Wild_ (79).jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#

# %%
plt.imshow(RGB_img)

# %%
RGB_img
# Out:
# array([[[  0,   0,   0],
#         [ 93, 105, 118],
#         [ 93, 105, 117],
#         ...,
#         [ 76,  82,  85],
#         [ 76,  82,  85],
#         [ 76,  82,  86]],
#
#        [[  0,   0,   0],
#         [ 93, 105, 119],
#         [ 93, 105, 118],
#         ...,
#         [ 74,  79,  84],
#         [ 74,  79,  84],
#         [ 74,  79,  85]],
#
#        [[  0,   0,   0],
#         [ 92, 104, 118],
#         [ 92, 104, 117],
#         ...,
#         [ 78,  82,  92],
#         [ 76,  80,  90],
#         [ 76,  79,  89]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [103, 113, 122],
#         [106, 114, 124],
#         ...,
#         [135, 163, 191],
#         [135, 163, 191],
#         [135, 163, 191]],
#
#        [[  0,   0,   0],
#         [101, 109, 119],
#         [105, 114, 123],
#         ...,
#         [136, 163, 191],
#         [136, 163, 191],
#         [136, 163, 191]],
#
#        [[  0,   0,   0],
#         [ 99, 107, 116],
#         [105, 113, 122],
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SagarghotekarKalu-Co\\Desktop\\sai_pro'

# %%
import os
import cv2
import numpy as np
folder_path = r"C:\Users\SagarghotekarKalu-Co\Desktop\New folder"

file_list = os.listdir(folder_path)

file_list
# Out:
# ['wdfgh (1).jpg',
#  'wdfgh (1).png',
#  'wdfgh (10).png',
#  'wdfgh (11).png',
#  'wdfgh (12).png',
#  'wdfgh (13).png',
#  'wdfgh (14).png',
#  'wdfgh (15).png',
#  'wdfgh (16).png',
#  'wdfgh (17).png',
#  'wdfgh (18).png',
#  'wdfgh (19).png',
#  'wdfgh (2).jpg',
#  'wdfgh (2).png',
#  'wdfgh (20).png',
#  'wdfgh (21).png',
#  'wdfgh (22).png',
#  'wdfgh (23).png',
#  'wdfgh (24).png',
#  'wdfgh (25).png',
#  'wdfgh (26).png',
#  'wdfgh (27).png',
#  'wdfgh (28).png',
#  'wdfgh (29).png',
#  'wdfgh (3).jpg',
#  'wdfgh (3).png',
#  'wdfgh (30).png',
#  'wdfgh (31).png',
#  'wdfgh (32).png',
#  'wdfgh (33).png',
#  'wdfgh (34).png',
#  'wdfgh (35).png',
#  'wdfgh (36).png',
#  'wdfgh (37).png',
#  'wdfgh (38).png',
#  'wdfgh (39).png',
#  'wdfgh (4).jpg',
#  'wdfgh (4).png',
#  'wdfgh (40).png',
#  'wdfgh (41).png',
#  'wdfgh (42).png',
#  'wdfgh (43).png',
#  'wdfgh (44).png',
#  'wdfgh (45).png',
#  'wdfgh (46).png',
#  'wdfgh (5).jpg',
#  'wdfgh (5).png',
#  'wdfgh (6).jpg',
# ...

# %%
lis=[]
for i in list(range(1,len(file_list))):
    for file in file_list:
        if file.endswith('.jpg') or file.endswith('.png'):
            if file_list[i]!=file:
                image1 = cv2.imread(os.path.join(folder_path,file_list[i]))
                #RGB_img1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
                image = cv2.imread(os.path.join(folder_path,file))
                #RGB_img=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                if image1.shape == image.shape :
                    if np.all(image==image1):
                        lis.append(file_list[i])
    print(file_list[i])
# Out:
# wdfgh (1).png
# wdfgh (10).png
# wdfgh (11).png
# wdfgh (12).png
# wdfgh (13).png
# wdfgh (14).png
# wdfgh (15).png
# wdfgh (16).png
# wdfgh (17).png
# wdfgh (18).png
# wdfgh (19).png
# wdfgh (2).jpg
# wdfgh (2).png
# wdfgh (20).png
# wdfgh (21).png
# wdfgh (22).png
# wdfgh (23).png
# wdfgh (24).png
# wdfgh (25).png
# wdfgh (26).png
# wdfgh (27).png
# wdfgh (28).png
# wdfgh (29).png
# wdfgh (3).jpg
# wdfgh (3).png
# wdfgh (30).png
# wdfgh (31).png
# wdfgh (32).png
# wdfgh (33).png
# wdfgh (34).png
# wdfgh (35).png
# wdfgh (36).png
# wdfgh (37).png
# wdfgh (38).png
# wdfgh (39).png
# wdfgh (4).jpg
# wdfgh (4).png
# wdfgh (40).png
# wdfgh (41).png
# wdfgh (42).png
# wdfgh (43).png
# wdfgh (44).png
# wdfgh (45).png
# wdfgh (46).png
# wdfgh (5).jpg
# wdfgh (5).png
# wdfgh (6).jpg
# wdfgh (6).png
# wdfgh (7).jpg
# wdfgh (7).png
# wdfgh (8).png
# wdfgh (9).png

# %%
lis
# Out:
# ['wdfgh (1).png',
#  'wdfgh (10).png',
#  'wdfgh (11).png',
#  'wdfgh (12).png',
#  'wdfgh (13).png',
#  'wdfgh (14).png',
#  'wdfgh (15).png',
#  'wdfgh (16).png',
#  'wdfgh (17).png',
#  'wdfgh (18).png',
#  'wdfgh (19).png',
#  'wdfgh (2).png',
#  'wdfgh (20).png',
#  'wdfgh (3).png',
#  'wdfgh (4).png',
#  'wdfgh (5).png',
#  'wdfgh (6).png',
#  'wdfgh (7).png',
#  'wdfgh (8).png',
#  'wdfgh (9).png']

# %%
for i in lis:
    plt.imshow(i)
    plt.waitforbuttonpress()
    plt.close('all')

# %%
lis=[]
for i in file_list:
    for file in file_list:
        if file.endswith('.jpg') or file.endswith('.png'):
            if i!=file:
                image1=cv2.imread(i)
                #RGB_img1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
                image = cv2.imread(file)
                #RGB_img=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                if image1 == image:
                    lis.extend((file_list[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       9 #RGB_img=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      10 if image1 == image:
# ---> 11     lis.extend((file_list[i]))
#
# TypeError: list indices must be integers or slices, not str

# %%
np.all(np.array(image)==np.array(image1))
# Out:
# True

# %%
img=cv2.imread(i)
plt.show(img)

# %%
im=cv2.imread("_",i)
cv2.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 im=cv2.imread("_",i)
#       2 cv2.imshow(im)
#
# TypeError: Argument 'flags' is required to be an integer

# %%
image

# %%
lis
# Out:
# [6,
#  7,
#  8,
#  9,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  16,
#  16,
#  16,
#  16]

# %%
import numpy as np

# %%
image1.any()
# Out:
# True

# %%
image.any()
# Out:
# True

# %%
import datetime
import time

def print_live_time():
  """Prints the current live time."""
  now = datetime.datetime.now()
  print(now.strftime("%H:%M:%S"))

# Start a loop to print the live time every 10 seconds.
while True:
  print_live_time()
  time.sleep(10)
# Out:
# 17:55:39
# 17:55:49
# 17:55:59
# 17:56:09
# 17:56:19
# 17:56:29
# 17:56:39
# 17:56:49
# 17:56:59
# 17:57:09
# 17:57:19
# 17:57:29
# 17:57:39
# 17:57:49
# 17:57:59
# 17:58:09
# 17:58:19
# 17:58:29
# 17:58:39
# 17:58:49
# 17:58:59
